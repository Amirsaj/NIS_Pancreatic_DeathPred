# %%
import h2o
import pandas as pd
from h2o.automl import H2OAutoML
from h2o.estimators import H2ODeepLearningEstimator
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "1.8.0_352"; OpenJDK Runtime Environment (build 1.8.0_352-b08); OpenJDK 64-Bit Server VM (build 25.352-b08, mixed mode)
#   Starting server from /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp5kjbng_a
#   JVM stdout: /tmp/tmp5kjbng_a/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmp5kjbng_a/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       America/Chicago
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.4
# H2O_cluster_version_age:    3 days
# H2O_cluster_name:           H2O_from_python_unknownUser_4aeabp
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    26.63 Gb
# H2O_cluster_total_cores:    25
# H2O_cluster_allowed_cores:  25
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.7 final
# --------------------------  ----------------------------------

# %% [markdown]
# # LOS Data Loading

# %%
X = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/X.csv')  
Y = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/Y.csv')

# %%
X = X.drop(['Unnamed: 0','NCI','CCI'], axis=1)
X['died'] = Y['died']

# %%
col = X.columns

# %%
data = h2o.H2OFrame(X)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
target = 'los'
features = []
for i in col:
    if i != target:
        features.append(i)

# %%
train, test = data.split_frame(ratios=[0.8])

# %% [markdown]
# # Data Loading

# %%
X = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/X_Cleared_Balance1.5.csv')  
Y = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/Y_Cleared_Balance1.5.csv')

# %%
y1 = Y['0']
xe = X
xe = xe.drop(['Unnamed: 0'], axis=1)


for i in xe.columns:
    if i == 'age':
        continue
    xe[i] = xe[i].astype('category')
    
y1 = y1.astype('category')

# %%
xe['died'] = y1

# %%
data = h2o.H2OFrame(xe)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
data['los'] = []

# %%
col = xe.columns

# %%
for i in col:
    if i in ['drg_nopoa','los','pl_nchs','totchg','zipinc_qrtl']:
          continue
    data[i] = data[i].enum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_149563/2716420002.py in <module>
#       2     if i in ['drg_nopoa','los','pl_nchs','totchg','zipinc_qrtl']:
#       3           continue
# ----> 4     data[i] = data[i].enum
#
# AttributeError: 'H2OFrame' object has no attribute 'enum'

# %%
data['died'] = data['died'].asfactor()

# %%
train, test = data.split_frame(ratios=[0.8])

# %%
target = 'los'
features = []
for i in xe.columns:
    if i != target:
        features.append(i)

# %%
# Out:
# False

# %% [markdown]
# # Traditional

# %%
clf = H2OAutoML(max_models=30, seed=42)
clf.train(x=features, y=target, training_frame=train)
# Out:
# AutoML progress: |
# 16:49:41.825: _train param, Dropping bad and constant columns: [RSP004, EAR001, SKB010, hcup_ed2.0, EYE004, PNS002, NEO009, PNS003, MUS004, FRS004, GIS014, END017, INF011, URN012, INJ076, NEO016, ENT015, NEO051, RHB003, age_neonate, CAR019, MRS003, FAC003, INF001, CAR015, URN007, NEO048, MHT003, PRG028, MHT002]
#
# █
# 16:49:47.518: _train param, Dropping bad and constant columns: [RSP004, EAR001, SKB010, hcup_ed2.0, EYE004, PNS002, NEO009, PNS003, MUS004, FRS004, GIS014, END017, INF011, URN012, INJ076, NEO016, ENT015, NEO051, RHB003, age_neonate, CAR019, MRS003, FAC003, INF001, CAR015, URN007, NEO048, MHT003, PRG028, MHT002]
#
# ██
# 16:49:53.926: _train param, Dropping bad and constant columns: [RSP004, EAR001, SKB010, hcup_ed2.0, EYE004, PNS002, NEO009, PNS003, MUS004, FRS004, GIS014, END017, INF011, URN012, INJ076, NEO016, ENT015, NEO051, RHB003, age_neonate, CAR019, MRS003, FAC003, INF001, CAR015, URN007, NEO048, MHT003, PRG028, MHT002]
#
# █ (cancelled)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_173135/2700460978.py in <module>
#       1 clf = H2OAutoML(max_models=30, seed=42)
# ----> 2 clf.train(x=features, y=target, training_frame=train)
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/automl/_estimator.py in train(self, x, y, training_frame, fold_column, weights_column, validation_frame, leaderboard_frame, blending_frame)
#     677         poll_updates = ft.partial(self._poll_training_updates, verbosity=self._verbosity, state={})
#     678         try:
# --> 679             self._job.poll(poll_updates=poll_updates)
#     680         finally:
#     681             poll_updates(self._job, 1)
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/job.py in poll(self, poll_updates)
#      74         except StopIteration as e:
#      75             if str(e) == "cancelled":
# ---> 76                 self.cancel()
#      77             # Potentially we may want to re-raise the exception here
#      78
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/job.py in cancel(self)
#     104
#     105     def cancel(self):
# --> 106         h2o.api("POST /3/Jobs/%s/cancel" % self.job_key)
#     107         self.status = "CANCELLED"
#     108
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/h2o.py in api(endpoint, data, json, filename, save_to)
#     122     # type checks are performed in H2OConnection class
#     123     _check_connection()
# --> 124     return h2oconn.request(endpoint, data=data, json=json, filename=filename, save_to=save_to)
#     125
#     126
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/backend/connection.py in request(self, endpoint, data, json, filename, save_to)
#     492                 self._log_start_transaction(endpoint, rd, json, filename, params)
#     493                 args = self._request_args()
# --> 494                 resp = requests.request(method=method, url=url, data=rd, json=json, params=params,
#     495                                         stream=stream, **args)
#     496                 if isinstance(save_to, types.FunctionType):
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
perf = clf.leader.model_performance(test_data=xtest)
print(perf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_149563/196806632.py in <module>
# ----> 1 perf = clf.leader.model_performance(test_data=xtest)
#       2 print(perf)
#
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/model/model_base.py in model_performance(self, test_data, train, valid, xval, auc_type, auuc_type, auuc_nbins)
#     505         else:  # cases dealing with test_data not None
#     506             if not isinstance(test_data, h2o.H2OFrame):
# --> 507                 raise ValueError("`test_data` must be of type H2OFrame.  Got: " + type(test_data))
#     508             if (self._model_json["response_column_name"] is not None) and not(self._model_json["response_column_name"] in test_data.names):
#     509                 print("WARNING: Model metrics cannot be calculated and metric_json is empty due to the absence of the response column in your dataset.")
#
# TypeError: can only concatenate str (not "type") to str

# %% [markdown]
# # DeepLearning

# %%
dl = H2ODeepLearningEstimator(
                           distribution = 'tweedie',
                           #hidden=[1],
                           epochs=100,
                           train_samples_per_iteration=-1,
                           reproducible=True,
                           activation="Tanh",
                           single_node_mode=False,
                           balance_classes=False,
                           force_load_balance=False,
                           seed=42,
                           score_training_samples=0,
                           score_validation_samples=0,
                           stopping_rounds=0)

# %%
dl.train(x=features,
      y=target,
      training_frame=data)
# Out:
# deeplearning Model Build progress: |
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/h2o/estimators/estimator_base.py:193: RuntimeWarning: Dropping bad and constant columns: [i10_birth, NEO051]
#   warnings.warn(mesg["message"], RuntimeWarning)
# █████████████████████████████████████████████

# %%
perf = dl.model_performance(test)
perf
# Out:
# ModelMetricsRegression: deeplearning
# ** Reported on test data. **
#
# MSE: 5.534343599025443
# RMSE: 2.3525185650756177
# MAE: 1.2333941296476427
# RMSLE: 0.2215696637554893
# Mean Residual Deviance: 0.2080991145457506

# %%
pred = dl.predict(test)
pred
# Out:
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
#   predict
# ---------
#  29.2702
#  10.0073
#   3.7933
#  13.677
#   8.28088
#   4.62163
#   3.29844
#   9.03734
#   1.54439
#   1.48075
# [17190 rows x 1 column]

# %%
test['los']
# Out:
#   los
# -----
#    25
#     9
#     3
#    13
#     8
#     5
#     3
#    12
#     1
#     2
# [17190 rows x 1 column]

# %%
leader_model = dl
explanation = leader_model.explain(test)
print(explanation)
# Out:
# # Residual Analysis
# > Residual Analysis plots the fitted values vs residuals on a test dataset. Ideally, residuals should be randomly distributed. Patterns in this plot can indicate potential problems with the model selection, e.g., using simpler model than necessary, not accounting for heteroscedasticity, autocorrelation, etc. Note that if you see "striped" lines of residuals, that is an artifact of having an integer valued (vs a real valued) response variable.
# # Learning Curve Plot
# > Learning curve plot shows the loss function/metric dependent on number of iterations or trees for tree-based algorithms. This plot can be useful for determining whether the model overfits.
# # Variable Importance
# > The variable importance plot shows the relative importance of the most important variables in the model.
# # Partial Dependence Plots
# > Partial dependence plot (PDP) gives a graphical depiction of the marginal effect of a variable on the response. The effect of a variable is measured in change in the mean response. PDP assumes independence between the feature for which is the PDP computed and the rest.
# # Individual Conditional Expectation
# > An Individual Conditional Expectation (ICE) plot gives a graphical depiction of the marginal effect of a variable on the response. ICE plots are similar to partial dependence plots (PDP); PDP shows the average effect of a feature while ICE plot shows the effect for a single instance. This function will plot the effect for each decile. In contrast to the PDP, ICE plots can provide more insight, especially when there is stronger feature interaction.
# H2OExplanation([('residual_analysis', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x2afbbdc5d850>), ('description', <h2o.explanation._explain.Description object at 0x2afbbe38afa0>), ('plots', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbd8b3f70>)]))])), ('learning_curve', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x2afbb8dd0cd0>), ('description', <h2o.explanation._explain.Description object at 0x2afbbe19af70>), ('plots', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbd8eb1f0>)]))])), ('varimp', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x2afbbdaf1160>), ('description', <h2o.explanation._explain.Description object at 0x2afbbc97fa30>), ('plots', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbc76f520>)]))])), ('pdp', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x2afbbd94ef40>), ('description', <h2o.explanation._explain.Description object at 0x2afbbd8eb9d0>), ('plots', H2OExplanation([('totchg', <h2o.plot._plot_result._MObject object at 0x2afbbc870fa0>), ('i10_npr', <h2o.plot._plot_result._MObject object at 0x2afbbc926340>), ('i10_ndx', <h2o.plot._plot_result._MObject object at 0x2afbba5060a0>), ('dispuniform', <h2o.plot._plot_result._MObject object at 0x2afbbc6db250>), ('died', <h2o.plot._plot_result._MObject object at 0x2afbbd93cbb0>)]))])), ('ice', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x2afbbc8b3460>), ('description', <h2o.explanation._explain.Description object at 0x2afbbd99db50>), ('plots', H2OExplanation([('totchg', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbc688400>)])), ('i10_npr', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbc642490>)])), ('i10_ndx', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbc76b2b0>)])), ('dispuniform', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbe741a90>)])), ('died', H2OExplanation([('DeepLearning_model_python_1682975901469_22', <h2o.plot._plot_result._MObject object at 0x2afbbc88e190>)]))]))]))])

# %%
summary = dl.summary()
print(summary.as_data_frame())
# Out:
#      layer  units    type dropout   l1   l2 mean_rate  rate_rms momentum  \
# 0        1    650   Input     0.0
# 1        2    200    Tanh     0.0  0.0  0.0  0.164155  0.192924      0.0
# 2        3    200    Tanh     0.0  0.0  0.0  0.020912  0.031109      0.0
# 3        4      1  Linear          0.0  0.0  0.000398  0.000003      0.0
#
#   mean_weight weight_rms mean_bias  bias_rms
# 0
# 1    0.012176   0.408237  0.044167  0.733836
# 2   -0.001708   0.496004 -0.019287  2.490405
# 3   -0.002895   0.065551  4.425064       0.0
