# %%
# import Libraries 
from scipy.sparse import csr_matrix
import pandas as pd
import plotly.express as px
from sklearn.metrics import precision_n_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score,precision_score,recall_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MaxAbsScaler
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
import graphviz 
from sklearn.feature_selection import SelectKBest , f_regression
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn import datasets, ensemble
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import max_error,mean_squared_error,mean_absolute_error,mean_squared_log_error,r2_score
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import RidgeClassifierCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import top_k_accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve
# from sklearn.inspection import DecisionBoundaryDisplay
import numpy as np
import seaborn as sns
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report,confusion_matrix
import os
import pickle
import plotly.graph_objs as go
import plotly.offline as pyo
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
# import modin.pandas as mpd
import multiprocessing
import swifter
import ray
import warnings
# Out:
# Package pickle5 becomes unnecessary in Python 3.8 and above. Its presence may confuse libraries including Ray. Please uninstall the package.

# %%
'FAC010' in X.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 'FAC010' in X.columns
#
# NameError: name 'X' is not defined

# %% [markdown]
# # loading Data

# %%
X = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/X_Cleared_Balance1.5.csv')  
Y = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/Y_Cleared_Balance1.5.csv')

# %%
y1 = Y['0']
xe = X
xe = xe.drop(['Unnamed: 0'], axis=1)
for i in xe.columns:
    if i == 'age':
        continue
    xe[i] = xe[i].astype('category')
    
y1 = y1.astype('category')

# %% [markdown]
# K best :

# %%
X_t = SelectKBest(chi2,k=24)
X_t.fit_transform(xe,y1)
fet = []
Columnss = xe.columns
cont= 0
for i in X_t.get_support():
    fet.append(Columnss[cont]) if i==True else 0
    cont +=1
print(fet)
X_t=X_t.fit_transform(xe,y1)
X_train, X_test, y_train, y_test = train_test_split(X_t, y1, test_size=0.2, random_state=42)
# Out:
# ['hosp_division7.0', 'hosp_division6.0', 'hosp_division5.0', 'hosp_division4.0', 'hosp_division2.0', 'drg_nopoa', 'i10_necause', 'i10_npr', 'los', 'mdc', 'mdc_nopoa', 'totchg', 'BLD006', 'CIR018', 'DIG018', 'GEN002', 'INF002', 'NVS020', 'RSP002', 'RSP010', 'SYM003', 'ADM006', 'CAR024', 'ESA005']

# %% [markdown]
# All of Data:

# %%
X_train, X_test, y_train, y_test = train_test_split(xe, y1, test_size = 0.2,random_state=42)

# %%
def reportTheAccRecallPercesion
# Out:
# /raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/New_version

# %%
def report(y_true, model_name , name, thresholds=None):
    os.makedirs(name, exist_ok=True)
    filename = os.path.join(name, name+'.sav')
    pickle.dump(model_name, open(filename, 'wb'))
    y_pred = model_name.predict(X_test)
    # Print model name
    
    print("Model: {}".format(name))
    print("========================")
    
    if hasattr(model_name, "predict_proba"):
        y_prob = model_name.predict_proba(X_test)[:, 1]
        fpr, tpr, thresholds = roc_curve(y_true, y_prob)
        indx = np.argmax(tpr-fpr)
        threshold = thresholds[indx]
   
    else:
        threshold = [0.5]
        y_prob = y_pred

    younY = y_prob >= threshold
    younY = younY.astype(int)

    accuracy = accuracy_score(y_true, younY)
    f1metric =  f1_score(y_true, younY)
    precision = precision_score(y_true, younY)
    recalll = recall_score(y_true, younY)

    balancedAcc = balanced_accuracy_score(y_true, younY)

    print("Threshold:", threshold)
    print("========================")
    # Calculate sensitivity and specificity
    cm = confusion_matrix(y_true, younY)
    tp = cm[0, 0]
    fn = cm[0, 1]
    fp = cm[1, 0]
    tn = cm[1, 1]

    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    # Print the results
    auc = roc_auc_score(y_test, y_prob)
    
    #feture_importance
    # FeatureImportance = os.path.join(name, "Feature_importance.png")
    # importances = model_name.feature_importances_
    # sorted_indices = np.argsort(importances)[::-1]
    # feat_labels = fet
    # for f in range(X_train.shape[1]):
    #     print("%2d) %-*s %f" % (f + 1, 30,
    #                             feat_labels[sorted_indices[f]],
    #                             importances[sorted_indices[f]]))
    
    
    print("Sensitivity:", sensitivity)
    print("Specificity:", specificity)
    print("========================")
    print('precision :', precision)
    print('accuracy :', accuracy)
    print('balancedAcc :', balancedAcc)
    print('recalll :', recalll)
    print('f1metric :', f1metric)
    print('AUC:', auc)
    print("========================")

    print(classification_report(y_true, younY))
    
    
    
    result_file_name = os.path.join(name, "results.txt")
    with open(result_file_name, 'w') as f:
        f.write("Threshold: {}\n".format(threshold))
        f.write("========================\n")
        f.write("Sensitivity: {}\n".format(sensitivity))
        f.write("Specificity: {}\n".format(specificity))
        f.write("========================\n")
        f.write("Precision: {}\n".format(precision))
        f.write("Accuracy: {}\n".format(accuracy))
        f.write("Recall: {}\n".format(recalll))
        f.write("F1 Score: {}\n".format(f1metric))
        f.write("========================\n")
        f.write("AUC: {}\n".format(auc))
        f.write("========================\n")
        f.write("Classification Report:\n{}\n".format(classification_report(y_test, younY)))
    plot_file_name = os.path.join(name, "ROC_plot")
    trace1 = go.Scatter(x=fpr, y=tpr, name='ROC curve (area = %0.2f)' % auc)
    trace2 = go.Scatter(x=[0, 1], y=[0, 1], line=dict(dash='dash'), name='Random guess')
    fig = go.Figure(data=[trace1, trace2])
    fig.update_layout(
        title="{} - ROC".format(name),
        title_x=0.5,
        xaxis_title="False Positive Rate",
        yaxis_title="True Positive Rate",
        legend=dict(x=0.65, y=0.09, bordercolor="Black", borderwidth=2),
        width=1200,
        height=800)
    pyo.plot(fig, filename=plot_file_name, auto_open=False)
    # Save the plot in png format
    plot_file_name = os.path.join(name, "ROC_plot.png")
    fig.write_image(plot_file_name,width=950, height=750)
    df = pd.DataFrame({
        'False Positive Rate': fpr,
        'True Positive Rate': tpr
    }, index=thresholds)
    df.index.name = "Thresholds"
    df.columns.name = "Rate"
    
    fig_thresh = px.imshow(
        df,
        x=df.columns,
        y=df.index,
        title="TPR and FPR at every threshold",
        color_continuous_scale='YlOrRd'
    )
    plot_thresh_file_name = os.path.join(name, "TPR_FPR_heatmap.html")
    fig_thresh.write_html(plot_thresh_file_name)
    plot_thresh_png_file_name = os.path.join(name, "TPR_FPR_heatmap.png")
    fig_thresh.write_image(plot_thresh_png_file_name)
    
    fig_thresh = px.line(df, title='TPR and FPR at every threshold', width=950, height=750)
    fig_thresh.update_layout(title='TPR and FPR at every threshold', title_x=0.5)
    fig_thresh.update_yaxes(scaleanchor="x", scaleratio=1)
    fig_thresh.update_xaxes(range=[0, 1], constrain='domain')
    
    
    thresh_plot_file_name = os.path.join(name, "TPR_FPR_plot.html")
    fig_thresh.write_html(thresh_plot_file_name)
    fig_thresh.write_image(os.path.join(name, "TPR_FPR_plot.png"))
    
    
    cm_file_name = os.path.join(name, "confusion_matrix.png")
    cm_fig = go.Figure(data=go.Heatmap(z=cm, x=['Predicted: 0', 'Predicted: 1'], y=['Actual: 0', 'Actual: 1'], colorscale="Blues"))
    for i in range(len(cm)):
        for j in range(len(cm)):
            cm_fig.add_annotation(x=j, y=i, text=str(cm[i][j]), showarrow=False, font=dict(color='gray', size=20))
            
    cm_fig.update_layout(
        title="Confusion Matrix for {}".format(name),
        title_x=0.5,
        xaxis_title="Predicted label",
        yaxis_title="True label",
        width=950,
        height=750
    )
    cm_fig.write_image(cm_file_name)
    cm_file_name = os.path.join(name, "confusion_matrix.html")
    
    fig2 = go.Figure(data=go.Heatmap(z=cm, x=["Predicted Negative", "Predicted Positive"], y=["Actual Negative", "Actual Positive"], colorscale="Blues"))
    fig2.update_layout(
        title="Confusion Matrix for {}".format(name),
        xaxis_title="Predicted label",
        yaxis_title="True label",
        width=1600,
        height=1200
    )
    pyo.plot(fig2, filename=cm_file_name, auto_open=False)
    print("Results and plot saved in folder:", name)

    print("Results saved in {}".format(name))

    
    
    
    #return accuracy, balancedAcc, f1metric, recalll, precision, sensitivity, specificity

# %%
def reportCCINCI(y_true, y_prob , name, thresholds=None):
    os.makedirs('Reports/'+name, exist_ok=True)
#    y_pred = model_name.predict(X_test)
    # Print model name
    
    print("Model: {}".format(name))
    print("========================")
    
    fpr, tpr, thresholds = roc_curve(y_true, y_prob)
    indx = np.argmax(tpr-fpr)
    threshold = thresholds[indx]


    younY = y_prob >= threshold
    younY = younY.astype(int)

    accuracy = accuracy_score(y_true, younY)
    balancedAcc = balanced_accuracy_score(y_true, younY)
    f1metric =  f1_score(y_true, younY)
    recalll = recall_score(y_true, younY)
    precision = precision_score(y_true, younY)

    print("Threshold:", threshold)
    print("========================")
    # Calculate sensitivity and specificity
    cm = confusion_matrix(y_true, younY)
    tp = cm[0, 0]
    fn = cm[0, 1]
    fp = cm[1, 0]
    tn = cm[1, 1]

    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    # Print the results
    auc = roc_auc_score(y_true, y_prob)
    
    print("Sensitivity:", sensitivity)
    print("Specificity:", specificity)
    print("========================")
    print('precision :', precision)
    print('accuracy :', accuracy)
    print('balancedAcc :', balancedAcc)
    print('recalll :', recalll)
    print('f1metric :', f1metric)
    print('AUC:', auc)
    print("========================")

    print(classification_report(y_true, younY))
    
    
    
    result_file_name = os.path.join(name, "results.txt")
    with open(result_file_name, 'w') as f:
        f.write("Threshold: {}\n".format(threshold))
        f.write("========================\n")
        f.write("Sensitivity: {}\n".format(sensitivity))
        f.write("Specificity: {}\n".format(specificity))
        f.write("========================\n")
        f.write("Precision: {}\n".format(precision))
        f.write("Accuracy: {}\n".format(accuracy))
        f.write("Recall: {}\n".format(recalll))
        f.write("F1 Score: {}\n".format(f1metric))
        f.write("========================\n")
        f.write("AUC: {}\n".format(auc))
        f.write("========================\n")
        f.write("Classification Report:\n{}\n".format(classification_report(y_true, younY)))
    plot_file_name = os.path.join(name, "ROC_plot")
    trace1 = go.Scatter(x=fpr, y=tpr, name='ROC curve (area = %0.2f)' % auc)
    trace2 = go.Scatter(x=[0, 1], y=[0, 1], line=dict(dash='dash'), name='Random guess')
    fig = go.Figure(data=[trace1, trace2])
    fig.update_layout(
        title="{} - ROC".format(name),
        title_x=0.5,
        xaxis_title="False Positive Rate",
        yaxis_title="True Positive Rate",
        legend=dict(x=0.65, y=0.09, bordercolor="Black", borderwidth=2),
        width=1200,
        height=800)
    pyo.plot(fig, filename=plot_file_name, auto_open=False)
    # Save the plot in png format
    plot_file_name = os.path.join(name, "ROC_plot.png")
    fig.write_image(plot_file_name,width=950, height=750)
    df = pd.DataFrame({
        'False Positive Rate': fpr,
        'True Positive Rate': tpr
    }, index=thresholds)
    df.index.name = "Thresholds"
    df.columns.name = "Rate"
    
    fig_thresh = px.imshow(
        df,
        x=df.columns,
        y=df.index,
        title="TPR and FPR at every threshold",
        color_continuous_scale='YlOrRd'
    )
    plot_thresh_file_name = os.path.join(name, "TPR_FPR_heatmap.html")
    fig_thresh.write_html(plot_thresh_file_name)
    plot_thresh_png_file_name = os.path.join(name, "TPR_FPR_heatmap.png")
    fig_thresh.write_image(plot_thresh_png_file_name)
    
    fig_thresh = px.line(df, title='TPR and FPR at every threshold', width=950, height=750)
    fig_thresh.update_layout(title='TPR and FPR at every threshold', title_x=0.5)
    fig_thresh.update_yaxes(scaleanchor="x", scaleratio=1)
    fig_thresh.update_xaxes(range=[0, 1], constrain='domain')
    
    
    thresh_plot_file_name = os.path.join(name, "TPR_FPR_plot.html")
    fig_thresh.write_html(thresh_plot_file_name)
    fig_thresh.write_image(os.path.join(name, "TPR_FPR_plot.png"))
    
    
    cm_file_name = os.path.join(name, "confusion_matrix.png")
    cm_fig = go.Figure(data=go.Heatmap(z=cm, x=['Predicted: 0', 'Predicted: 1'], y=['Actual: 0', 'Actual: 1'], colorscale="Blues"))
    for i in range(len(cm)):
        for j in range(len(cm)):
            cm_fig.add_annotation(x=j, y=i, text=str(cm[i][j]), showarrow=False, font=dict(color='gray', size=20))
            
    cm_fig.update_layout(
        title="Confusion Matrix for {}".format(name),
        title_x=0.5,
        xaxis_title="Predicted label",
        yaxis_title="True label",
        width=950,
        height=750
    )
    cm_fig.write_image(cm_file_name)
    cm_file_name = os.path.join(name, "confusion_matrix.html")
    
    fig2 = go.Figure(data=go.Heatmap(z=cm, x=["Predicted Negative", "Predicted Positive"], y=["Actual Negative", "Actual Positive"], colorscale="Blues"))
    fig2.update_layout(
        title="Confusion Matrix for {}".format(name),
        xaxis_title="Predicted label",
        yaxis_title="True label",
        width=1600,
        height=1200
    )
    pyo.plot(fig2, filename=cm_file_name, auto_open=False)
    print("Results and plot saved in folder:", name)

    print("Results saved in {}".format(name))

    
    
    
    #return accuracy, balancedAcc, f1metric, recalll, precision, sensitivity, specificity

# %%
def reportDeeplearnin(y_true, model_name , name, thresholds=None):
    global X_train, X_test, y_train, y_test
    os.makedirs('Reports/'+name, exist_ok=True)
    # filename = os.path.join(name, name+'.sav')
    # pickle.dump(model_name, open(filename, 'wb'))
    y_pred1 = model_name.predict(X_test)
    # Print model name
    
    print("Model: {}".format(name))
    print("========================")
    
    y_pred = []
    for i in y_pred1 : 
        y_pred.append(i[1])
    y_prob = y_pred

    #y_prob = model_name.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_true, y_prob)
    indx = np.argmax(tpr-fpr)
    threshold = thresholds[indx]

    df = pd.DataFrame({
        'False Positive Rate': fpr,
        'True Positive Rate': tpr
    }, index=thresholds)
    df.index.name = "Thresholds"
    df.columns.name = "Rate"
    younY = y_prob >= threshold
    younY = younY.astype(int)

    accuracy = accuracy_score(y_true, younY)
    balancedAcc = balanced_accuracy_score(y_true, younY)
    f1metric =  f1_score(y_true, younY)
    recalll = recall_score(y_true, younY)
    precision = precision_score(y_true, younY)

    print("Threshold:", threshold)
    print("========================")
    # Calculate sensitivity and specificity
    cm = confusion_matrix(y_true, younY)
    tp = cm[0, 0]
    fn = cm[0, 1]
    fp = cm[1, 0]
    tn = cm[1, 1]

    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    # Print the results
    auc = roc_auc_score(y_test, y_prob)
    
    #feture_importance
    # FeatureImportance = os.path.join(name, "Feature_importance.png")
    # importances = model_name.feature_importances_
    # sorted_indices = np.argsort(importances)[::-1]
    # feat_labels = fet
    # for f in range(X_train.shape[1]):
    #     print("%2d) %-*s %f" % (f + 1, 30,
    #                             feat_labels[sorted_indices[f]],
    #                             importances[sorted_indices[f]]))
    
    
    print("Sensitivity:", sensitivity)
    print("Specificity:", specificity)
    print("========================")
    print('precision :', precision)
    print('accuracy :', accuracy)
    print('balancedAcc :', balancedAcc)
    print('recalll :', recalll)
    print('f1metric :', f1metric)
    print('AUC:', auc)
    print("========================")

    print(classification_report(y_true, younY))
    
    
    
    result_file_name = os.path.join('Reports/'+name, "results.txt")
    with open(result_file_name, 'w') as f:
        f.write("Threshold: {}\n".format(threshold))
        f.write("========================\n")
        f.write("Sensitivity: {}\n".format(sensitivity))
        f.write("Specificity: {}\n".format(specificity))
        f.write("========================\n")
        f.write("Precision: {}\n".format(precision))
        f.write("Accuracy: {}\n".format(accuracy))
        f.write("Recall: {}\n".format(recalll))
        f.write("F1 Score: {}\n".format(f1metric))
        f.write("========================\n")
        f.write("AUC: {}\n".format(auc))
        f.write("========================\n")
        f.write("Classification Report:\n{}\n".format(classification_report(y_test, younY)))
    plot_file_name = os.path.join('Reports/'+name, "ROC_plot")
    trace1 = go.Scatter(x=fpr, y=tpr, name='ROC curve (area = %0.2f)' % auc)
    trace2 = go.Scatter(x=[0, 1], y=[0, 1], line=dict(dash='dash'), name='Random guess')
    fig = go.Figure(data=[trace1, trace2])
    fig.update_layout(
        title="{} - ROC".format(name),
        title_x=0.5,
        xaxis_title="False Positive Rate",
        yaxis_title="True Positive Rate",
        legend=dict(x=0.65, y=0.09, bordercolor="Black", borderwidth=2),
        width=1200,
        height=800)
    pyo.plot(fig, filename=plot_file_name, auto_open=False)
    # Save the plot in png format
    plot_file_name = os.path.join('Reports/'+name, "ROC_plot.png")
    fig.write_image(plot_file_name,width=950, height=750)
    df = pd.DataFrame({
        'False Positive Rate': fpr,
        'True Positive Rate': tpr
    }, index=thresholds)
    df.index.name = "Thresholds"
    df.columns.name = "Rate"
    df.to_csv('Reports/'+name+'/'+'NN_Threshold.csv')
    fig_thresh = px.imshow(
        df,
        x=df.columns,
        y=df.index,
        title="TPR and FPR at every threshold",
        color_continuous_scale='YlOrRd'
    )
    plot_thresh_file_name = os.path.join('Reports/'+name, "TPR_FPR_heatmap.html")
    fig_thresh.write_html(plot_thresh_file_name)
    plot_thresh_png_file_name = os.path.join('Reports/'+name, "TPR_FPR_heatmap.png")
    fig_thresh.write_image(plot_thresh_png_file_name)
    
    fig_thresh = px.line(df, title='TPR and FPR at every threshold', width=950, height=750)
    fig_thresh.update_layout(title='TPR and FPR at every threshold', title_x=0.5)
    fig_thresh.update_yaxes(scaleanchor="x", scaleratio=1)
    fig_thresh.update_xaxes(range=[0, 1], constrain='domain')
    
    
    thresh_plot_file_name = os.path.join('Reports/'+name, "TPR_FPR_plot.html")
    fig_thresh.write_html(thresh_plot_file_name)
    fig_thresh.write_image(os.path.join('Reports/'+name, "TPR_FPR_plot.png"))
    
    
    cm_file_name = os.path.join('Reports/'+name, "confusion_matrix.png")
    cm_fig = go.Figure(data=go.Heatmap(z=cm, x=['Predicted: 0', 'Predicted: 1'], y=['Actual: 0', 'Actual: 1'], colorscale="Blues"))
    for i in range(len(cm)):
        for j in range(len(cm)):
            cm_fig.add_annotation(x=j, y=i, text=str(cm[i][j]), showarrow=False, font=dict(color='gray', size=20))
            
    cm_fig.update_layout(
        title="Confusion Matrix for {}".format(name),
        title_x=0.5,
        xaxis_title="Predicted label",
        yaxis_title="True label",
        width=950,
        height=750
    )
    cm_fig.write_image(cm_file_name)
    cm_file_name = os.path.join('Reports/'+name, "confusion_matrix.html")
    
    fig2 = go.Figure(data=go.Heatmap(z=cm, x=["Predicted Negative", "Predicted Positive"], y=["Actual Negative", "Actual Positive"], colorscale="Blues"))
    fig2.update_layout(
        title="Confusion Matrix for {}".format(name),
        xaxis_title="Predicted label",
        yaxis_title="True label",
        width=1600,
        height=1200
    )
    pyo.plot(fig2, filename=cm_file_name, auto_open=False)
    print("Results and plot saved in folder:", name)

    print("Results saved in {}".format(name))

    
    
    
    #return accuracy, balancedAcc, f1metric, recalll, precision, sensitivity, specificity

# %% [markdown]
# # Deep Learning

# %%
X = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/X_Cleared_Balance1.5.csv')  
Y = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/Y_Cleared_Balance1.5.csv')
y1 = Y['0']
xe = X
xe = xe.drop(['Unnamed: 0'], axis=1)

y1 = y1.astype('category')

# %% [markdown]
# # All in one

# %%
# Load Model 
import pickle as pkl
from keras.models import load_model
for FirstLayer in [10,25,50,100]:
    for SecondLayer in [10,25,50,100]: 
        for epoch in [10,25,50,100]:
            try:
                X = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/X_Cleared_Balance1.5.csv')  
                Y = pd.read_csv('/raid-18/CHS/jakeluo/share/notebook/ataleban@uwm.edu/Panc_/Y_Cleared_Balance1.5.csv')
                y1 = Y['0']
                xe = X
                xe = xe.drop(['Unnamed: 0'], axis=1)
                model = load_model('Hidden'+str(FirstLayer)+'_'+str(SecondLayer)+'Epoch'+str(epoch)+'.hdf5')
                # modify the Data based on METADATA
                with open('Hidden'+str(FirstLayer)+'_'+str(SecondLayer)+'Epoch'+str(epoch)+'.pkl', 'rb') as file:
                    MetaData = pkl.load(file)
                MetaData['Features'].remove('died')
                xe = xe[MetaData['Features']]
                # print(type(xe))
                # print(len(MetaData['norm']))
                # xe[0]
                xe = xe*MetaData['norm']
                for i in xe.columns:
                    if i == 'age':
                        continue
                    xe[i] = xe[i].astype('category')

                X_train, X_test, y_train, y_test = train_test_split(xe, y1, test_size = 0.4,random_state=42)
                reportDeeplearnin(y_test, model,str(FirstLayer)+'_'+str(SecondLayer)+'_'+str(epoch)+'NN')
            except :
                pass
# Out:
# 202/202 [==============================] - 0s 1ms/step
# Model: 10_10_25NN
# ========================
# Threshold: 0.44676778
# ========================
# Sensitivity: 0.8186034527183715
# Specificity: 0.8190364277320799
# ========================
# precision : 0.7481216457960644
# accuracy : 0.8187752564501088
# balancedAcc : 0.8188199402252256
# recalll : 0.8190364277320799
# f1metric : 0.7819745699326851
# AUC: 0.8976581299940363
# ========================
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      3881
#            1       0.75      0.82      0.78      2553
#
#     accuracy                           0.82      6434
#    macro avg       0.81      0.82      0.81      6434
# weighted avg       0.82      0.82      0.82      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_10_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_10_25NN
# Results saved in 10_10_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 10_10_50NN
# ========================
# Threshold: 0.36704594
# ========================
# Sensitivity: 0.8155114661169801
# Specificity: 0.8139443791617704
# ========================
# precision : 0.7437365783822477
# accuracy : 0.8148896487410631
# balancedAcc : 0.8147279226393753
# recalll : 0.8139443791617704
# f1metric : 0.7772582756685991
# AUC: 0.887009417357938
# ========================
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      3881
#            1       0.74      0.81      0.78      2553
#
#     accuracy                           0.81      6434
#    macro avg       0.81      0.81      0.81      6434
# weighted avg       0.82      0.81      0.82      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_10_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_10_50NN
# Results saved in 10_10_50NN
# 202/202 [==============================] - 0s 960us/step
# Model: 10_10_100NN
# ========================
# Threshold: 0.38096926
# ========================
# Sensitivity: 0.8144808039165163
# Specificity: 0.8292205248726988
# ========================
# precision : 0.7462107860415932
# accuracy : 0.820329499533727
# balancedAcc : 0.8218506643946075
# recalll : 0.8292205248726988
# f1metric : 0.7855287569573283
# AUC: 0.8889398904522752
# ========================
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.85      3881
#            1       0.75      0.83      0.79      2553
#
#     accuracy                           0.82      6434
#    macro avg       0.81      0.82      0.82      6434
# weighted avg       0.83      0.82      0.82      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_10_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_10_100NN
# Results saved in 10_10_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 10_25_25NN
# ========================
# Threshold: 0.40603
# ========================
# Sensitivity: 0.8433393455295027
# Specificity: 0.854680767724246
# ========================
# precision : 0.782078853046595
# accuracy : 0.8478396021137706
# balancedAcc : 0.8490100566268743
# recalll : 0.854680767724246
# f1metric : 0.8167696050907729
# AUC: 0.9210857115924164
# ========================
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87      3881
#            1       0.78      0.85      0.82      2553
#
#     accuracy                           0.85      6434
#    macro avg       0.84      0.85      0.84      6434
# weighted avg       0.85      0.85      0.85      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_25_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_25_25NN
# Results saved in 10_25_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 10_25_50NN
# ========================
# Threshold: 0.42310965
# ========================
# Sensitivity: 0.8410203555784591
# Specificity: 0.8018018018018018
# ========================
# precision : 0.7683933933933934
# accuracy : 0.8254585017096674
# balancedAcc : 0.8214110786901305
# recalll : 0.8018018018018018
# f1metric : 0.7847421889975082
# AUC: 0.8903359573233991
# ========================
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      3881
#            1       0.77      0.80      0.78      2553
#
#     accuracy                           0.83      6434
#    macro avg       0.82      0.82      0.82      6434
# weighted avg       0.83      0.83      0.83      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_25_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_25_50NN
# Results saved in 10_25_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 10_25_100NN
# ========================
# Threshold: 0.5258953
# ========================
# Sensitivity: 0.826591084771966
# Specificity: 0.7865256560908734
# ========================
# precision : 0.7489742633345766
# accuracy : 0.8106931924152938
# balancedAcc : 0.8065583704314196
# recalll : 0.7865256560908734
# f1metric : 0.7672907909820404
# AUC: 0.8705571237863452
# ========================
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      3881
#            1       0.75      0.79      0.77      2553
#
#     accuracy                           0.81      6434
#    macro avg       0.80      0.81      0.80      6434
# weighted avg       0.81      0.81      0.81      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_25_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_25_100NN
# Results saved in 10_25_100NN
# 202/202 [==============================] - 0s 855us/step
# Model: 10_50_25NN
# ========================
# Threshold: 0.3538828
# ========================
# Sensitivity: 0.7930945632568925
# Specificity: 0.8370544457500979
# ========================
# precision : 0.7268707482993197
# accuracy : 0.8105377681069319
# balancedAcc : 0.8150745045034953
# recalll : 0.8370544457500979
# f1metric : 0.7780811942472238
# AUC: 0.8979363341024947
# ========================
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83      3881
#            1       0.73      0.84      0.78      2553
#
#     accuracy                           0.81      6434
#    macro avg       0.80      0.82      0.81      6434
# weighted avg       0.82      0.81      0.81      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_50_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_50_25NN
# Results saved in 10_50_25NN
# 202/202 [==============================] - 0s 873us/step
# Model: 10_50_50NN
# ========================
# Threshold: 0.42709932
# ========================
# Sensitivity: 0.846946663231126
# Specificity: 0.8460634547591069
# ========================
# precision : 0.7843137254901961
# accuracy : 0.8465962076468759
# balancedAcc : 0.8465050589951164
# recalll : 0.8460634547591069
# f1metric : 0.8140192198982477
# AUC: 0.9140284207221236
# ========================
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      3881
#            1       0.78      0.85      0.81      2553
#
#     accuracy                           0.85      6434
#    macro avg       0.84      0.85      0.84      6434
# weighted avg       0.85      0.85      0.85      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_50_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_50_50NN
# Results saved in 10_50_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 10_50_100NN
# ========================
# Threshold: 0.38549268
# ========================
# Sensitivity: 0.8224684359701108
# Specificity: 0.8280454367410889
# ========================
# precision : 0.754191937210132
# accuracy : 0.8246813801678583
# balancedAcc : 0.8252569363555998
# recalll : 0.8280454367410889
# f1metric : 0.7893950709484691
# AUC: 0.8916975577686062
# ========================
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      3881
#            1       0.75      0.83      0.79      2553
#
#     accuracy                           0.82      6434
#    macro avg       0.82      0.83      0.82      6434
# weighted avg       0.83      0.82      0.83      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_50_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_50_100NN
# Results saved in 10_50_100NN
# 202/202 [==============================] - 0s 882us/step
# Model: 10_100_25NN
# ========================
# Threshold: 0.44508547
# ========================
# Sensitivity: 0.8320020613244009
# Specificity: 0.8057187622405013
# ========================
# precision : 0.7593207825765965
# accuracy : 0.8215728940006217
# balancedAcc : 0.8188604117824512
# recalll : 0.8057187622405013
# f1metric : 0.781832003040669
# AUC: 0.8958724865371518
# ========================
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85      3881
#            1       0.76      0.81      0.78      2553
#
#     accuracy                           0.82      6434
#    macro avg       0.81      0.82      0.82      6434
# weighted avg       0.82      0.82      0.82      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_100_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_100_25NN
# Results saved in 10_100_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 10_100_50NN
# ========================
# Threshold: 0.46589714
# ========================
# Sensitivity: 0.8428240144292708
# Specificity: 0.8131609870740305
# ========================
# precision : 0.7728965003723008
# accuracy : 0.8310537768106931
# balancedAcc : 0.8279925007516507
# recalll : 0.8131609870740305
# f1metric : 0.7925176560412293
# AUC: 0.9028509537511027
# ========================
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86      3881
#            1       0.77      0.81      0.79      2553
#
#     accuracy                           0.83      6434
#    macro avg       0.82      0.83      0.83      6434
# weighted avg       0.83      0.83      0.83      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_100_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_100_50NN
# Results saved in 10_100_50NN
# 202/202 [==============================] - 0s 875us/step
# Model: 10_100_100NN
# ========================
# Threshold: 0.4500574
# ========================
# Sensitivity: 0.7982478742592115
# Specificity: 0.7763415589502546
# ========================
# precision : 0.7168173598553346
# accuracy : 0.7895554864780852
# balancedAcc : 0.787294716604733
# recalll : 0.7763415589502546
# f1metric : 0.745393004889056
# AUC: 0.865833255367553
# ========================
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82      3881
#            1       0.72      0.78      0.75      2553
#
#     accuracy                           0.79      6434
#    macro avg       0.78      0.79      0.78      6434
# weighted avg       0.79      0.79      0.79      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/10_100_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 10_100_100NN
# Results saved in 10_100_100NN
# 202/202 [==============================] - 0s 876us/step
# Model: 25_10_25NN
# ========================
# Threshold: 0.3536199
# ========================
# Sensitivity: 0.8737438804431847
# Specificity: 0.9044261652957305
# ========================
# precision : 0.8249374776705967
# accuracy : 0.8859185576624184
# balancedAcc : 0.8890850228694576
# recalll : 0.9044261652957305
# f1metric : 0.8628550074738416
# AUC: 0.9543361741136855
# ========================
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      3881
#            1       0.82      0.90      0.86      2553
#
#     accuracy                           0.89      6434
#    macro avg       0.88      0.89      0.88      6434
# weighted avg       0.89      0.89      0.89      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_10_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_10_25NN
# Results saved in 25_10_25NN
# 202/202 [==============================] - 0s 920us/step
# Model: 25_10_50NN
# ========================
# Threshold: 0.3555384
# ========================
# Sensitivity: 0.8539036330842567
# Specificity: 0.8922835879357619
# ========================
# precision : 0.8007029876977153
# accuracy : 0.869132732359341
# balancedAcc : 0.8730936105100093
# recalll : 0.8922835879357619
# f1metric : 0.8440163023341979
# AUC: 0.9440232946612971
# ========================
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.89      3881
#            1       0.80      0.89      0.84      2553
#
#     accuracy                           0.87      6434
#    macro avg       0.86      0.87      0.87      6434
# weighted avg       0.87      0.87      0.87      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_10_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_10_50NN
# Results saved in 25_10_50NN
# 202/202 [==============================] - 0s 874us/step
# Model: 25_10_100NN
# ========================
# Threshold: 0.3207635
# ========================
# Sensitivity: 0.872197887142489
# Specificity: 0.8491970231100666
# ========================
# precision : 0.8138138138138138
# accuracy : 0.8630711843332297
# balancedAcc : 0.8606974551262778
# recalll : 0.8491970231100666
# f1metric : 0.8311290013417674
# AUC: 0.9314020730116985
# ========================
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      3881
#            1       0.81      0.85      0.83      2553
#
#     accuracy                           0.86      6434
#    macro avg       0.86      0.86      0.86      6434
# weighted avg       0.86      0.86      0.86      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_10_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_10_100NN
# Results saved in 25_10_100NN
# 202/202 [==============================] - 0s 870us/step
# Model: 25_25_25NN
# ========================
# Threshold: 0.56772
# ========================
# Sensitivity: 0.8997681010048957
# Specificity: 0.8695652173913043
# ========================
# precision : 0.850900728248371
# accuracy : 0.8877836493627603
# balancedAcc : 0.8846666591981001
# recalll : 0.8695652173913043
# f1metric : 0.8601317318868655
# AUC: 0.9538408264756248
# ========================
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      3881
#            1       0.85      0.87      0.86      2553
#
#     accuracy                           0.89      6434
#    macro avg       0.88      0.88      0.88      6434
# weighted avg       0.89      0.89      0.89      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_25_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_25_25NN
# Results saved in 25_25_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 25_25_50NN
# ========================
# Threshold: 0.43493605
# ========================
# Sensitivity: 0.9072404019582582
# Specificity: 0.9048178613396005
# ========================
# precision : 0.8651685393258427
# accuracy : 0.9062791420578178
# balancedAcc : 0.9060291316489293
# recalll : 0.9048178613396005
# f1metric : 0.8845491097070649
# AUC: 0.9657527866080121
# ========================
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92      3881
#            1       0.87      0.90      0.88      2553
#
#     accuracy                           0.91      6434
#    macro avg       0.90      0.91      0.90      6434
# weighted avg       0.91      0.91      0.91      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_25_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_25_50NN
# Results saved in 25_25_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 25_25_100NN
# ========================
# Threshold: 0.38066912
# ========================
# Sensitivity: 0.903117753156403
# Specificity: 0.9146102624363494
# ========================
# precision : 0.8613057912209516
# accuracy : 0.9076779608330743
# balancedAcc : 0.9088640077963761
# recalll : 0.9146102624363494
# f1metric : 0.8871580547112462
# AUC: 0.9679446595358002
# ========================
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      3881
#            1       0.86      0.91      0.89      2553
#
#     accuracy                           0.91      6434
#    macro avg       0.90      0.91      0.90      6434
# weighted avg       0.91      0.91      0.91      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_25_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_25_100NN
# Results saved in 25_25_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 25_50_25NN
# ========================
# Threshold: 0.34135517
# ========================
# Sensitivity: 0.9013140943055914
# Specificity: 0.900117508813161
# ========================
# precision : 0.8571428571428571
# accuracy : 0.9008392912651538
# balancedAcc : 0.9007158015593761
# recalll : 0.900117508813161
# f1metric : 0.8781047000382117
# AUC: 0.9602110092122752
# ========================
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      3881
#            1       0.86      0.90      0.88      2553
#
#     accuracy                           0.90      6434
#    macro avg       0.89      0.90      0.90      6434
# weighted avg       0.90      0.90      0.90      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_50_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_50_25NN
# Results saved in 25_50_25NN
# 202/202 [==============================] - 0s 946us/step
# Model: 25_50_50NN
# ========================
# Threshold: 0.37554142
# ========================
# Sensitivity: 0.9639268229837671
# Specificity: 0.954563258911085
# ========================
# precision : 0.9456732634846721
# accuracy : 0.9602113770593721
# balancedAcc : 0.959245040947426
# recalll : 0.954563258911085
# f1metric : 0.9500974658869396
# AUC: 0.9913844027866634
# ========================
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      3881
#            1       0.95      0.95      0.95      2553
#
#     accuracy                           0.96      6434
#    macro avg       0.96      0.96      0.96      6434
# weighted avg       0.96      0.96      0.96      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_50_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_50_50NN
# Results saved in 25_50_50NN
# 202/202 [==============================] - 0s 925us/step
# Model: 25_50_100NN
# ========================
# Threshold: 0.43389797
# ========================
# Sensitivity: 0.9688224684359701
# Specificity: 0.9659224441833137
# ========================
# precision : 0.9532276768457673
# accuracy : 0.9676717438607398
# balancedAcc : 0.967372456309642
# recalll : 0.9659224441833137
# f1metric : 0.959533073929961
# AUC: 0.992730460539071
# ========================
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3881
#            1       0.95      0.97      0.96      2553
#
#     accuracy                           0.97      6434
#    macro avg       0.97      0.97      0.97      6434
# weighted avg       0.97      0.97      0.97      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_50_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_50_100NN
# Results saved in 25_50_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 25_100_25NN
# ========================
# Threshold: 0.5049459
# ========================
# Sensitivity: 0.8325173924246329
# Specificity: 0.7833920877399139
# ========================
# precision : 0.7547169811320755
# accuracy : 0.8130245570407212
# balancedAcc : 0.8079547400822733
# recalll : 0.7833920877399139
# f1metric : 0.7687872381318471
# AUC: 0.8866385626521405
# ========================
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      3881
#            1       0.75      0.78      0.77      2553
#
#     accuracy                           0.81      6434
#    macro avg       0.80      0.81      0.81      6434
# weighted avg       0.81      0.81      0.81      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_100_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_100_25NN
# Results saved in 25_100_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 25_100_50NN
# ========================
# Threshold: 0.342258
# ========================
# Sensitivity: 0.8188611182684875
# Specificity: 0.8190364277320799
# ========================
# precision : 0.7483894058697208
# accuracy : 0.8189306807584706
# balancedAcc : 0.8189487730002837
# recalll : 0.8190364277320799
# f1metric : 0.7821208154105106
# AUC: 0.8943498577389439
# ========================
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.85      3881
#            1       0.75      0.82      0.78      2553
#
#     accuracy                           0.82      6434
#    macro avg       0.81      0.82      0.81      6434
# weighted avg       0.82      0.82      0.82      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_100_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_100_50NN
# Results saved in 25_100_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 25_100_100NN
# ========================
# Threshold: 0.12553376
# ========================
# Sensitivity: 0.7598557072919351
# Specificity: 0.8237367802585194
# ========================
# precision : 0.6929159802306425
# accuracy : 0.785203605843954
# balancedAcc : 0.7917962437752273
# recalll : 0.8237367802585194
# f1metric : 0.7526843235504652
# AUC: 0.8692676858434227
# ========================
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      3881
#            1       0.69      0.82      0.75      2553
#
#     accuracy                           0.79      6434
#    macro avg       0.78      0.79      0.78      6434
# weighted avg       0.80      0.79      0.79      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/25_100_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 25_100_100NN
# Results saved in 25_100_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_10_25NN
# ========================
# Threshold: 0.33861068
# ========================
# Sensitivity: 0.9026024220561711
# Specificity: 0.9063846455150802
# ========================
# precision : 0.8595839524517088
# accuracy : 0.9041032017407522
# balancedAcc : 0.9044935337856257
# recalll : 0.9063846455150802
# f1metric : 0.8823641563393708
# AUC: 0.9641293321597592
# ========================
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      3881
#            1       0.86      0.91      0.88      2553
#
#     accuracy                           0.90      6434
#    macro avg       0.90      0.90      0.90      6434
# weighted avg       0.91      0.90      0.90      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_10_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_10_25NN
# Results saved in 50_10_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_10_50NN
# ========================
# Threshold: 0.4920718
# ========================
# Sensitivity: 0.9474362277763463
# Specificity: 0.918527222875049
# ========================
# precision : 0.9199686151431934
# accuracy : 0.935965184954927
# balancedAcc : 0.9329817253256976
# recalll : 0.918527222875049
# f1metric : 0.9192473539788318
# AUC: 0.9808675507229221
# ========================
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      3881
#            1       0.92      0.92      0.92      2553
#
#     accuracy                           0.94      6434
#    macro avg       0.93      0.93      0.93      6434
# weighted avg       0.94      0.94      0.94      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_10_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_10_50NN
# Results saved in 50_10_50NN
# 202/202 [==============================] - 0s 906us/step
# Model: 50_10_100NN
# ========================
# Threshold: 0.1548575
# ========================
# Sensitivity: 0.9214120072146355
# Specificity: 0.9388954171562868
# ========================
# precision : 0.887120651369356
# accuracy : 0.9283493938451974
# balancedAcc : 0.9301537121854611
# recalll : 0.9388954171562868
# f1metric : 0.9122740247383445
# AUC: 0.979316157850377
# ========================
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      3881
#            1       0.89      0.94      0.91      2553
#
#     accuracy                           0.93      6434
#    macro avg       0.92      0.93      0.93      6434
# weighted avg       0.93      0.93      0.93      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_10_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_10_100NN
# Results saved in 50_10_100NN
# 202/202 [==============================] - 0s 921us/step
# Model: 50_25_25NN
# ========================
# Threshold: 0.3148246
# ========================
# Sensitivity: 0.9255346560164905
# Specificity: 0.9479044261652957
# ========================
# precision : 0.8933185677371724
# accuracy : 0.9344109418713087
# balancedAcc : 0.9367195410908931
# recalll : 0.9479044261652957
# f1metric : 0.9198023565184341
# AUC: 0.9822364178816461
# ========================
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      3881
#            1       0.89      0.95      0.92      2553
#
#     accuracy                           0.93      6434
#    macro avg       0.93      0.94      0.93      6434
# weighted avg       0.94      0.93      0.93      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_25_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_25_25NN
# Results saved in 50_25_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_25_50NN
# ========================
# Threshold: 0.37642935
# ========================
# Sensitivity: 0.948982221077042
# Specificity: 0.9463376419898158
# ========================
# precision : 0.9242540168324407
# accuracy : 0.9479328566987877
# balancedAcc : 0.9476599315334289
# recalll : 0.9463376419898158
# f1metric : 0.9351654731952778
# AUC: 0.9864977397997797
# ========================
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3881
#            1       0.92      0.95      0.94      2553
#
#     accuracy                           0.95      6434
#    macro avg       0.94      0.95      0.95      6434
# weighted avg       0.95      0.95      0.95      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_25_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_25_50NN
# Results saved in 50_25_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_25_100NN
# ========================
# Threshold: 0.26142156
# ========================
# Sensitivity: 0.9299149703684617
# Specificity: 0.9627888758323541
# ========================
# precision : 0.9003663003663004
# accuracy : 0.9429592788312092
# balancedAcc : 0.9463519231004078
# recalll : 0.9627888758323541
# f1metric : 0.930531894756767
# AUC: 0.98664413379917
# ========================
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      3881
#            1       0.90      0.96      0.93      2553
#
#     accuracy                           0.94      6434
#    macro avg       0.94      0.95      0.94      6434
# weighted avg       0.94      0.94      0.94      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_25_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_25_100NN
# Results saved in 50_25_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_50_25NN
# ========================
# Threshold: 0.46034527
# ========================
# Sensitivity: 0.9729451172378253
# Specificity: 0.9631805718762241
# ========================
# precision : 0.9590483619344774
# accuracy : 0.9690705626359962
# balancedAcc : 0.9680628445570247
# recalll : 0.9631805718762241
# f1metric : 0.961110025405511
# AUC: 0.9952117404253228
# ========================
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3881
#            1       0.96      0.96      0.96      2553
#
#     accuracy                           0.97      6434
#    macro avg       0.97      0.97      0.97      6434
# weighted avg       0.97      0.97      0.97      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_50_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_50_25NN
# Results saved in 50_50_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_50_50NN
# ========================
# Threshold: 0.37954372
# ========================
# Sensitivity: 0.9855707291935069
# Specificity: 0.9874657265961614
# ========================
# precision : 0.9782693053938688
# accuracy : 0.9863226608641592
# balancedAcc : 0.9865182278948341
# recalll : 0.9874657265961614
# f1metric : 0.9828460038986354
# AUC: 0.9988739621846285
# ========================
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3881
#            1       0.98      0.99      0.98      2553
#
#     accuracy                           0.99      6434
#    macro avg       0.98      0.99      0.99      6434
# weighted avg       0.99      0.99      0.99      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_50_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_50_50NN
# Results saved in 50_50_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_50_100NN
# ========================
# Threshold: 0.22440207
# ========================
# Sensitivity: 0.9920123679464056
# Specificity: 0.9941245593419507
# ========================
# precision : 0.987933047878552
# accuracy : 0.992850481815356
# balancedAcc : 0.9930684636441781
# recalll : 0.9941245593419507
# f1metric : 0.9910191331511129
# AUC: 0.9995411877826764
# ========================
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      3881
#            1       0.99      0.99      0.99      2553
#
#     accuracy                           0.99      6434
#    macro avg       0.99      0.99      0.99      6434
# weighted avg       0.99      0.99      0.99      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_50_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_50_100NN
# Results saved in 50_50_100NN
# 202/202 [==============================] - 0s 934us/step
# Model: 50_100_25NN
# ========================
# Threshold: 0.4601708
# ========================
# Sensitivity: 0.9178046895130121
# Specificity: 0.9059929494712103
# ========================
# precision : 0.8787993920972644
# accuracy : 0.9131178116257382
# balancedAcc : 0.9118988194921112
# recalll : 0.9059929494712103
# f1metric : 0.892189006750241
# AUC: 0.971121071218536
# ========================
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      3881
#            1       0.88      0.91      0.89      2553
#
#     accuracy                           0.91      6434
#    macro avg       0.91      0.91      0.91      6434
# weighted avg       0.91      0.91      0.91      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_100_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_100_25NN
# Results saved in 50_100_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_100_50NN
# ========================
# Threshold: 0.5104383
# ========================
# Sensitivity: 0.9479515588765782
# Specificity: 0.9443791617704661
# ========================
# precision : 0.9226942212016839
# accuracy : 0.9465340379235312
# balancedAcc : 0.9461653603235222
# recalll : 0.9443791617704661
# f1metric : 0.9334107626790553
# AUC: 0.9877799110291855
# ========================
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3881
#            1       0.92      0.94      0.93      2553
#
#     accuracy                           0.95      6434
#    macro avg       0.94      0.95      0.94      6434
# weighted avg       0.95      0.95      0.95      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_100_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_100_50NN
# Results saved in 50_100_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 50_100_100NN
# ========================
# Threshold: 0.13905299
# ========================
# Sensitivity: 0.9425405823241433
# Specificity: 0.9698394046220133
# ========================
# precision : 0.9173768062245276
# accuracy : 0.9533727074914516
# balancedAcc : 0.9561899934730783
# recalll : 0.9698394046220133
# f1metric : 0.9428789032749428
# AUC: 0.9920351773527221
# ========================
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96      3881
#            1       0.92      0.97      0.94      2553
#
#     accuracy                           0.95      6434
#    macro avg       0.95      0.96      0.95      6434
# weighted avg       0.95      0.95      0.95      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/50_100_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 50_100_100NN
# Results saved in 50_100_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_10_25NN
# ========================
# Threshold: 0.24181013
# ========================
# Sensitivity: 0.8652409172893584
# Specificity: 0.8687818253035644
# ========================
# precision : 0.8091937249179132
# accuracy : 0.8666459434255518
# balancedAcc : 0.8670113712964613
# recalll : 0.8687818253035644
# f1metric : 0.8379297317718171
# AUC: 0.9379593231581177
# ========================
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      3881
#            1       0.81      0.87      0.84      2553
#
#     accuracy                           0.87      6434
#    macro avg       0.86      0.87      0.86      6434
# weighted avg       0.87      0.87      0.87      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_10_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_10_25NN
# Results saved in 100_10_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_10_50NN
# ========================
# Threshold: 0.35593998
# ========================
# Sensitivity: 0.9263076526668385
# Specificity: 0.9353701527614571
# ========================
# precision : 0.8930441286462228
# accuracy : 0.9299036369288156
# balancedAcc : 0.9308389027141477
# recalll : 0.9353701527614571
# f1metric : 0.9137172374210828
# AUC: 0.9806262857415071
# ========================
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      3881
#            1       0.89      0.94      0.91      2553
#
#     accuracy                           0.93      6434
#    macro avg       0.92      0.93      0.93      6434
# weighted avg       0.93      0.93      0.93      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_10_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_10_50NN
# Results saved in 100_10_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_10_100NN
# ========================
# Threshold: 0.2825838
# ========================
# Sensitivity: 0.9309456325689255
# Specificity: 0.8969839404622013
# ========================
# precision : 0.8952306489444879
# accuracy : 0.9174696922598694
# balancedAcc : 0.9139647865155633
# recalll : 0.8969839404622013
# f1metric : 0.8961064370964587
# AUC: 0.9725417137110672
# ========================
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      3881
#            1       0.90      0.90      0.90      2553
#
#     accuracy                           0.92      6434
#    macro avg       0.91      0.91      0.91      6434
# weighted avg       0.92      0.92      0.92      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_10_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_10_100NN
# Results saved in 100_10_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_25_25NN
# ========================
# Threshold: 0.45397487
# ========================
# Sensitivity: 0.9118783818603453
# Specificity: 0.9016842929886408
# ========================
# precision : 0.8706505295007564
# accuracy : 0.9078333851414361
# balancedAcc : 0.9067813374244931
# recalll : 0.9016842929886408
# f1metric : 0.8858957090629208
# AUC: 0.966452106857426
# ========================
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      3881
#            1       0.87      0.90      0.89      2553
#
#     accuracy                           0.91      6434
#    macro avg       0.90      0.91      0.90      6434
# weighted avg       0.91      0.91      0.91      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_25_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_25_25NN
# Results saved in 100_25_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_25_50NN
# ========================
# Threshold: 0.52336997
# ========================
# Sensitivity: 0.9510435454779695
# Specificity: 0.9353701527614571
# ========================
# precision : 0.9262994569433669
# accuracy : 0.9448243705315511
# balancedAcc : 0.9432068491197133
# recalll : 0.9353701527614571
# f1metric : 0.9308127070746443
# AUC: 0.9861969786014464
# ========================
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      3881
#            1       0.93      0.94      0.93      2553
#
#     accuracy                           0.94      6434
#    macro avg       0.94      0.94      0.94      6434
# weighted avg       0.94      0.94      0.94      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_25_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_25_50NN
# Results saved in 100_25_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_25_100NN
# ========================
# Threshold: 0.19791369
# ========================
# Sensitivity: 0.9306879670188096
# Specificity: 0.9373286329808069
# ========================
# precision : 0.8989481592787378
# accuracy : 0.9333229717127759
# balancedAcc : 0.9340082999998083
# recalll : 0.9373286329808069
# f1metric : 0.9177372962607862
# AUC: 0.9818884735087416
# ========================
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      3881
#            1       0.90      0.94      0.92      2553
#
#     accuracy                           0.93      6434
#    macro avg       0.93      0.93      0.93      6434
# weighted avg       0.93      0.93      0.93      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_25_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_25_100NN
# Results saved in 100_25_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_50_25NN
# ========================
# Threshold: 0.36871216
# ========================
# Sensitivity: 0.9732027827879413
# Specificity: 0.9745397571484528
# ========================
# precision : 0.9598765432098766
# accuracy : 0.9737332918868511
# balancedAcc : 0.9738712699681971
# recalll : 0.9745397571484528
# f1metric : 0.9671525753158406
# AUC: 0.9956203416707768
# ========================
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      3881
#            1       0.96      0.97      0.97      2553
#
#     accuracy                           0.97      6434
#    macro avg       0.97      0.97      0.97      6434
# weighted avg       0.97      0.97      0.97      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_50_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_50_25NN
# Results saved in 100_50_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_50_50NN
# ========================
# Threshold: 0.21157125
# ========================
# Sensitivity: 0.9701107961865498
# Specificity: 0.9670975323149236
# ========================
# precision : 0.9551257253384913
# accuracy : 0.9689151383276344
# balancedAcc : 0.9686041642507367
# recalll : 0.9670975323149236
# f1metric : 0.9610743479953289
# AUC: 0.9942323993890713
# ========================
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3881
#            1       0.96      0.97      0.96      2553
#
#     accuracy                           0.97      6434
#    macro avg       0.97      0.97      0.97      6434
# weighted avg       0.97      0.97      0.97      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_50_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_50_50NN
# Results saved in 100_50_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_50_100NN
# ========================
# Threshold: 0.6393806
# ========================
# Sensitivity: 0.9703684617366658
# Specificity: 0.9588719153936546
# ========================
# precision : 0.9551307062036676
# accuracy : 0.9658066521603978
# balancedAcc : 0.9646201885651602
# recalll : 0.9588719153936546
# f1metric : 0.9569976544175137
# AUC: 0.9929283775558269
# ========================
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3881
#            1       0.96      0.96      0.96      2553
#
#     accuracy                           0.97      6434
#    macro avg       0.96      0.96      0.96      6434
# weighted avg       0.97      0.97      0.97      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_50_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_50_100NN
# Results saved in 100_50_100NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_100_25NN
# ========================
# Threshold: 0.45629552
# ========================
# Sensitivity: 0.9677918062355063
# Specificity: 0.9706227967097533
# ========================
# precision : 0.9519784863618901
# accuracy : 0.9689151383276344
# balancedAcc : 0.9692073014726298
# recalll : 0.9706227967097533
# f1metric : 0.9612102404965089
# AUC: 0.994691766702566
# ========================
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3881
#            1       0.95      0.97      0.96      2553
#
#     accuracy                           0.97      6434
#    macro avg       0.97      0.97      0.97      6434
# weighted avg       0.97      0.97      0.97      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_100_25NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_100_25NN
# Results saved in 100_100_25NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_100_50NN
# ========================
# Threshold: 0.3594058
# ========================
# Sensitivity: 0.9732027827879413
# Specificity: 0.9780650215432825
# ========================
# precision : 0.9600153787004998
# accuracy : 0.9751321106621076
# balancedAcc : 0.9756339021656119
# recalll : 0.9780650215432825
# f1metric : 0.9689561505626698
# AUC: 0.9966938472030167
# ========================
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      3881
#            1       0.96      0.98      0.97      2553
#
#     accuracy                           0.98      6434
#    macro avg       0.97      0.98      0.97      6434
# weighted avg       0.98      0.98      0.98      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_100_50NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_100_50NN
# Results saved in 100_100_50NN
# 202/202 [==============================] - 0s 1ms/step
# Model: 100_100_100NN
# ========================
# Threshold: 0.29103136
# ========================
# Sensitivity: 0.9765524349394485
# Specificity: 0.9788484136310224
# ========================
# precision : 0.9648648648648649
# accuracy : 0.977463475287535
# balancedAcc : 0.9777004242852354
# recalll : 0.9788484136310224
# f1metric : 0.9718063387128136
# AUC: 0.9971810197883711
# ========================
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      3881
#            1       0.96      0.98      0.97      2553
#
#     accuracy                           0.98      6434
#    macro avg       0.98      0.98      0.98      6434
# weighted avg       0.98      0.98      0.98      6434
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Reports/100_100_100NN/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: 100_100_100NN
# Results saved in 100_100_100NN

# %%
# Load Model 
import pickle as pkl
from keras.models import load_model
model = load_model('Hidden50_50Epoch10.hdf5')
# modify the Data based on METADATA
with open('metaData.pkl', 'rb') as file:
    MetaData = pkl.load(file)
MetaData['Features'].remove('died')
xe = xe[MetaData['Features']]
# print(type(xe))
# print(len(MetaData['norm']))
# xe[0]
xe = xe*MetaData['norm']
for i in xe.columns:
    if i == 'age':
        continue
    xe[i] = xe[i].astype('category')
    
X_train, X_test, y_train, y_test = train_test_split(xe, y1, test_size = 0.2,random_state=42)

# %%
reportDeeplearnin(y_test, model,'Hidden50_50Epoch10newNew')
# Out:
# 101/101 [==============================] - 0s 1ms/step
# Model: Hidden50_50Epoch10newNew
# ========================
# Threshold: 0.98763925
# ========================
# Sensitivity: 0.7341188524590164
# Specificity: 0.7470355731225297
# ========================
# precision : 0.6454918032786885
# accuracy : 0.7391980105688529
# balancedAcc : 0.740577212790773
# recalll : 0.7470355731225297
# f1metric : 0.6925613777940638
# AUC: 0.8140295956716128
# ========================
#               precision    recall  f1-score   support
#
#            0       0.82      0.73      0.77      1952
#            1       0.65      0.75      0.69      1265
#
#     accuracy                           0.74      3217
#    macro avg       0.73      0.74      0.73      3217
# weighted avg       0.75      0.74      0.74      3217
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Hidden50_50Epoch10newNew/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: Hidden50_50Epoch10newNew
# Results saved in Hidden50_50Epoch10newNew

# %% [markdown]
# # Machine Learning Models
#
# ## SGD

# %%
SGDclf = SGDClassifier(max_iter=1000, tol=1e-3,loss = 'log',random_state=42)
SGDclf.fit(X_train, y_train)
y_pred = SGDclf.predict(X_test)

# %%
report(y_test, SGDclf,'SGD')
# Out:
# Model: SGD
# ========================
# Threshold: 0.8387375320860966
# ========================
# Sensitivity: 0.7950540958268933
# Specificity: 0.8022064617809299
# ========================
# precision : 0.6055919095776323
# accuracy : 0.7970692717584369
# balancedAcc : 0.7986302788039117
# recalll : 0.8022064617809299
# f1metric : 0.6901694915254237
# AUC: 0.879253096366451
# ========================
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.80      0.85      3235
#          1.0       0.61      0.80      0.69      1269
#
#     accuracy                           0.80      4504
#    macro avg       0.76      0.80      0.77      4504
# weighted avg       0.83      0.80      0.80      4504
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `SGD/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: SGD
# Results saved in SGD

# %% [markdown]
# ### Decision Tree

# %%
tree_clf = DecisionTreeClassifier()
tree_clf.fit(X_train, y_train)
y_pred = tree_clf.predict(X_test)

# %%
report(y_test, tree_clf,'Decision_Tree')
# Out:
# Model: Decision_Tree
# ========================
# Threshold: 1.0
# ========================
# Sensitivity: 0.9354508196721312
# Specificity: 0.8782608695652174
# ========================
# precision : 0.8981406628940987
# accuracy : 0.9129623873173764
# balancedAcc : 0.9068558446186743
# recalll : 0.8782608695652174
# f1metric : 0.8880895283772982
# AUC: 0.9068558446186743
# ========================
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1952
#            1       0.90      0.88      0.89      1265
#
#     accuracy                           0.91      3217
#    macro avg       0.91      0.91      0.91      3217
# weighted avg       0.91      0.91      0.91      3217
# /raid-18/CHS/jakeluo/envs/Amirsajjad/lib/python3.10/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `Decision_Tree/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: Decision_Tree
# Results saved in Decision_Tree

# %% [markdown]
# # MLP

# %%
MLPclf = MLPClassifier(random_state=42, max_iter=500)
MLPclf.fit(X_train, y_train)
y_pred = MLPclf.predict(X_test)
# report(y_tes,t, y_pred, MLPclf)

# %%
report(y_test, MLPclf,'MLP')
# Out:
# Model: MLP
# ========================
# Threshold: 0.09834628139195463
# ========================
# Sensitivity: 0.8003091190108191
# Specificity: 0.7241922773837668
# ========================
# precision : 0.5872204472843451
# accuracy : 0.7788632326820604
# balancedAcc : 0.762250698197293
# recalll : 0.7241922773837668
# f1metric : 0.6485532815808045
# AUC: 0.8434068617599808
# ========================
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.80      0.84      3235
#          1.0       0.59      0.72      0.65      1269
#
#     accuracy                           0.78      4504
#    macro avg       0.73      0.76      0.74      4504
# weighted avg       0.80      0.78      0.79      4504
# /raid-18/CHS/jakeluo/envs/NIS2016/lib/python3.9/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `MLP/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: MLP
# Results saved in MLP

# %% [markdown]
# # Random Forest

# %%
RandomForestClassifier = RandomForestClassifier(max_depth= None, min_samples_leaf= 4, min_samples_split= 2, n_estimators= 200,random_state=42)
RandomForestClassifier.fit(X_train, y_train)
y_pred = RandomForestClassifier.predict(X_test)
# report(y_tes,t, y_pred, MLPclf)

# %%
report(y_test, RandomForestClassifier,'RandomForestClassifier')
# Out:
# Model: RandomForestClassifier
# ========================
# Threshold: 0.34410431338836645
# ========================
#  1) totchg                         0.104740
#  2) GEN002                         0.102723
#  3) drg_nopoa                      0.081313
#  4) INF002                         0.080375
#  5) los                            0.072384
#  6) hosp_division6.0               0.071295
#  7) NVS020                         0.058784
#  8) hosp_division4.0               0.058118
#  9) hosp_division5.0               0.049780
# 10) CIR018                         0.048146
# 11) i10_npr                        0.035915
# 12) DIG018                         0.029546
# 13) mdc_nopoa                      0.028463
# 14) mdc                            0.026488
# 15) SYM003                         0.024524
# 16) i10_necause                    0.022085
# 17) hosp_division7.0               0.021886
# 18) hosp_division2.0               0.019171
# 19) ESA005                         0.014063
# 20) RSP010                         0.012293
# 21) RSP002                         0.011146
# 22) BLD006                         0.010848
# 23) CAR024                         0.009126
# 24) ADM006                         0.006788
# Sensitivity: 0.8109631147540983
# Specificity: 0.8600790513833992
# ========================
# precision : 0.7467398764584763
# accuracy : 0.8302766552688841
# balancedAcc : 0.8355210830687487
# recalll : 0.8600790513833992
# f1metric : 0.7994121969140339
# AUC: 0.9181121622497246
# ========================
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85      1952
#            1       0.75      0.86      0.80      1265
#
#     accuracy                           0.83      3217
#    macro avg       0.82      0.84      0.83      3217
# weighted avg       0.84      0.83      0.83      3217
# UserWarning: Your filename `RandomForestClassifier/ROC_plot` didn't end with .html. Adding .html to the end of your file.
# Results and plot saved in folder: RandomForestClassifier
# Results saved in RandomForestClassifier

# %% [markdown]
# ## CCI NCI

# %%
y_prob = X['CCI']/X['CCI'].max()
y_true = Y['died']
reportCCINCI(y_true, y_prob,'CCI')

# %% [markdown]
# # MLPClassifier
